# %%
import pandas as pd
import numpy as np
import statds
from scipy.stats import friedmanchisquare

# %%
# Yes, you can program in R in a Jupyter notebook! 
# To do this, you need to install the R kernel for Jupyter.
# 
# Here are the steps:
# 
# 1. Make sure you have R installed on your system.
#    (Install from https://cran.r-project.org/)
#
# 2. Open R (or RStudio) and run the following to install the IRkernel package:
#    install.packages("IRkernel")
#
# 3. Then make the R kernel available to Jupyter:
#    IRkernel::installspec()
#
# 4. Now, when you open Jupyter Notebook or JupyterLab, you can create a new notebook and select the "R" kernel from the launcher.
#
# In an R Jupyter notebook, your code cells can be written in R, like this:
# 
# Example (R code):
# -----
# # Create a simple data frame
# df <- data.frame(
#   a = 1:5,
#   b = c("A", "B", "C", "D", "E")
# )
# print(df)
#
# # Run a t-test (as an example)
# t.test(1:5, y = 2:6)
# -----
#
# If you want, you can mix markdown cells for text and explanation, just as in a Python Jupyter notebook.
# Out:
# Friedman statistic: 3.0
# p-value: 0.3916251762710877
# Iman-Davenport statistic: 1.0
# p-value: 0.42622137926478976
